# %%
# !pip install pyspark[sql] tqdm fastparquet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark[sql]
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 43 kB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (4.64.1)
# Collecting fastparquet
#   Downloading fastparquet-2022.12.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 48.0 MB/s
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.8/dist-packages (from fastparquet) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastparquet) (21.3)
# Collecting cramjam>=2.3
#   Downloading cramjam-2.6.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 53.3 MB/s
# Collecting pandas>=1.5.0
#   Downloading pandas-1.5.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      |████████████████████████████████| 12.2 MB 39.6 MB/s
# Requirement already satisfied: fsspec in /usr/local/lib/python3.8/dist-packages (from fastparquet) (2022.11.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.5.0->fastparquet) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.5.0->fastparquet) (2022.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->fastparquet) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->fastparquet) (3.0.9)
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 62.6 MB/s
# Requirement already satisfied: pyarrow>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from pyspark[sql]) (9.0.0)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845512 sha256=3095ff72272a3713c199b25b41af75e8fae223d533e869a626d79f67070cc0b8
#   Stored in directory: /root/.cache/pip/wheels/43/dc/11/ec201cd671da62fa9c5cc77078235e40722170ceba231d7598
# Successfully built pyspark
# Installing collected packages: py4j, pyspark, pandas, cramjam, fastparquet
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.5
#     Uninstalling pandas-1.3.5:
#       Successfully uninstalled pandas-1.3.5
# Successfully installed cramjam-2.6.2 fastparquet-2022.12.0 pandas-1.5.2 py4j-0.10.9.5 pyspark-3.3.1

# %%
DRIVE_PATH = '/content/drive/MyDrive/data/extracted_parquet'

# %%
import numpy as np
import pandas as pd

from pyspark.sql import SparkSession
from pyspark.sql import types as T
from pyspark.sql import functions as F

from sklearn.metrics.pairwise import cosine_similarity

spark = SparkSession \
    .builder \
    .master('local[*]') \
    .appName("mocommender") \
    .getOrCreate()

# %%
metadata = spark.read.parquet(DRIVE_PATH + '/metadata/*.parquet')

# %% [markdown]
# ## MOVIE-GENRE MATRIX

# %%
movie_genre_df = spark.read.parquet(DRIVE_PATH + '/movie_genre/part-00000-caa98a46-cc9b-43ff-b8b7-f3761771e8d7-c000.snappy.parquet')
genre_df = spark.read.parquet(DRIVE_PATH + '/genre/part-00000-efc1790a-d5e2-4f82-9698-7cba71443f15-c000.snappy.parquet')

# %%
"""
2     [1, 3, 5]
3     [1, 2]
4     [8]


  |  1     2     3     5     8   
__|______________________________. . .
2 |  1     0     1     1     0   
--|------------------------------. . .
3 |  1     1     0     0     0   
--|------------------------------. . .
4 |  0     0     0     0     1   
  .
  .
  .

"""

df1 = movie_genre_df.select('id') \
                    .withColumnRenamed('id', 'movie_id')

df2 = genre_df.select('id') \
              .withColumnRenamed('id', 'genre_id')

M_df1_df2 = df1.crossJoin(df2) \
               .withColumn("w", F.lit(0))

M_df1_df2.show(4)
# Out:
# +--------+--------+---+
# |movie_id|genre_id|  w|
# +--------+--------+---+
# |       2|      12|  0|
# |       2|      14|  0|
# |       2|      16|  0|
# |       2|      18|  0|
# +--------+--------+---+
# only showing top 4 rows

# %%
exploded_movie_genre_df = movie_genre_df.select(F.col('id'),
                                                F.explode(F.col('genres'))) \
                                        .withColumnRenamed("id", "movie_id") \
                                        .withColumnRenamed("col", "genre_id")

# %%
M_movie_genre = M_df1_df2.join(exploded_movie_genre_df,
                               on=['movie_id', 'genre_id'],
                               how="full")\
                         .orderBy('movie_id', 'genre_id') \
                         .withColumn('w', 
                                     F.when(M_df1_df2.genre_id == exploded_movie_genre_df.genre_id, 1) \
                                      .otherwise(0))

# %%
M = M_movie_genre.groupby("movie_id") \
                 .pivot("genre_id") \
                 .sum("w") \
                 .fillna(0) \
                 .orderBy('movie_id')

# %%
movie_ids = M.select('movie_id').rdd.flatMap(lambda x: x).collect()
M_5000 = M.drop('movie_id')

# %%
dff = M_5000.toPandas()
#dff.to_parquet(DRIVE_PATH + '/matrices/dff', engine="fastparquet")

# %%
cosine_matrix = cosine_similarity(dff)
cosine_matrix_df = pd.DataFrame(cosine_matrix, movie_ids)

# %%
cosine_matrix_df
# Out:
#            0         1         2         3         4      5         6      \
# 2       1.000000  0.500000  0.500000  0.408248  0.000000    0.0  0.408248
# 3       0.500000  1.000000  0.500000  0.000000  0.000000    0.0  0.816497
# 5       0.500000  0.500000  1.000000  0.408248  0.000000    0.0  0.408248
# 6       0.408248  0.000000  0.408248  1.000000  0.333333    0.0  0.000000
# 11      0.000000  0.000000  0.000000  0.333333  1.000000    0.0  0.000000
# ...          ...       ...       ...       ...       ...    ...       ...
# 461634  0.000000  0.707107  0.707107  0.000000  0.000000    0.0  0.577350
# 461805  0.000000  0.000000  0.000000  0.000000  0.000000    0.0  0.000000
# 462788  0.500000  0.500000  0.000000  0.000000  0.000000    0.0  0.408248
# 463800  0.000000  0.000000  0.000000  0.333333  0.666667    0.0  0.000000
# 464111  0.000000  0.000000  0.000000  0.000000  0.408248    0.0  0.000000
#
#            7      8         9      ...    28991  28992     28993     28994  \
# 2       0.707107    0.5  0.816497  ...  0.00000    0.0  0.408248  0.353553
# 3       0.707107    0.5  0.408248  ...  0.00000    0.0  0.000000  0.353553
# 5       0.000000    0.0  0.408248  ...  0.00000    0.0  0.408248  0.707107
# 6       0.000000    0.0  0.333333  ...  0.57735    0.0  1.000000  0.577350
# 11      0.000000    0.0  0.000000  ...  0.57735    0.0  0.333333  0.288675
# ...          ...    ...       ...  ...      ...    ...       ...       ...
# 461634  0.000000    0.0  0.000000  ...  0.00000    0.0  0.000000  0.500000
# 461805  0.000000    0.0  0.000000  ...  0.00000    1.0  0.000000  0.000000
# 462788  0.707107    0.5  0.408248  ...  0.00000    0.0  0.000000  0.000000
# 463800  0.000000    0.0  0.000000  ...  0.57735    0.0  0.333333  0.288675
# 464111  0.000000    0.0  0.000000  ...  0.00000    0.0  0.000000  0.000000
#
#            28995     28996  28997  28998     28999     29000
# 2       0.000000  0.000000    0.0    0.5  0.000000  0.000000
# 3       0.000000  0.707107    0.0    0.5  0.000000  0.000000
# 5       0.000000  0.707107    0.0    0.0  0.000000  0.000000
# 6       0.000000  0.000000    0.0    0.0  0.333333  0.000000
# 11      0.408248  0.000000    0.0    0.0  0.666667  0.408248
# ...          ...       ...    ...    ...       ...       ...
# 461634  0.000000  1.000000    0.0    0.0  0.000000  0.000000
# 461805  0.000000  0.000000    1.0    0.0  0.000000  0.000000
# 462788  0.000000  0.000000    0.0    1.0  0.000000  0.000000
# 463800  0.408248  0.000000    0.0    0.0  1.000000  0.408248
# 464111  0.500000  0.000000    0.0    0.0  0.408248  1.000000
#
# [29001 rows x 29001 columns]

# %%
cosine_matrix_df.index.name = 'movie_id'

# %%
cosine_matrix_df.index = cosine_matrix_df.index.map(str)

# %%
cosine_matrix_df.columns = cosine_matrix_df.index

# %%
del dff, cosine_matrix, M, M_movie_genre, exploded_movie_genre_df, M_df1_df2, df2, df1, genre_df, movie_genre_df

# %%
a = 1381

# %%
chunks = {}
chunks_index = []

for i in range(21):
  cur_chunk = f'chunk_{i}'
  start = i*a
  end = (i+1)*a

  #chunks[cur_chunk] = cosine_matrix_df[start:end]
  #chunks_index[cur_chunk] = movie_ids[start:end]
  columns = movie_ids[start:end]
  d = pd.DataFrame([[i]*len(columns)], columns=columns)
  chunks_index.append(d)

# %%
for k, v in chunks.items():
  v.to_parquet(DRIVE_PATH + f'/__OUTPUT__/movie_genre/movie_genre_{k}')
  del v

# %%
df_chunks_index = pd.DataFrame(chunks_index)
df_chunks_index.to_parquet(DRIVE_PATH + f'/__OUTPUT__/movie_genre/index/movie_genre_index')

# %%
d = pd.concat(chunks_index, axis=1)
d.columns = d.columns.map(str)
d.to_parquet(DRIVE_PATH + f'/__OUTPUT__/movie_genre/index/movie_genre_index')

# %%
del cosine_matrix_df, chunks, chunks_index

# %%
df_chunks_index
# Out:
#       chunk_0  chunk_1  chunk_2  chunk_3  chunk_4  chunk_5  chunk_6  chunk_7  \
# 0           2     2661     9298    11376    14475    18595    24008    28627
# 1           3     2662     9299    11377    14476    18598    24010    28628
# 2           5     2665     9300    11378    14484    18602    24012    28632
# 3           6     2666     9301    11379    14489    18612    24014    28635
# 4          11     2667     9302    11380    14499    18613    24016    28638
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 1376     2642     9293    11371    14463    18587    24001    28601    34145
# 1377     2649     9294    11372    14464    18588    24002    28602    34148
# 1378     2652     9295    11373    14467    18589    24003    28605    34151
# 1379     2654     9296    11374    14469    18590    24004    28609    34152
# 1380     2655     9297    11375    14474    18591    24005    28614    34179
#
#       chunk_8  chunk_9  ...  chunk_11  chunk_12  chunk_13  chunk_14  chunk_15  \
# 0       34181    40192  ...     51828     62211     75638     88451    111149
# 1       34182    40205  ...     51832     62213     75656     88491    111174
# 2       34184    40206  ...     51836     62255     75674     88518    111188
# 3       34187    40208  ...     51848     62297     75720     88527    111190
# 4       34193    40210  ...     51851     62320     75733     88534    111237
# ...       ...      ...  ...       ...       ...       ...       ...       ...
# 1376    40162    44564  ...     62185     75612     88377    111043    142979
# 1377    40165    44566  ...     62186     75622     88390    111083    143049
# 1378    40168    44571  ...     62188     75623     88395    111100    143073
# 1379    40172    44578  ...     62204     75629     88418    111109    143092
# 1380    40180    44585  ...     62206     75634     88435    111114    143098
#
#       chunk_16  chunk_17  chunk_18  chunk_19  chunk_20
# 0       143142    192868    250833    297806    356201
# 1       143146    192911    250895    297853    356216
# 2       143240    192936    250902    297859    356294
# 3       143355    193177    250919    297961    356296
# 4       143380    193216    250989    298026    356298
# ...        ...       ...       ...       ...       ...
# 1376    192675    250658    297736    356156    461634
# 1377    192695    250666    297755    356161    461805
# 1378    192712    250700    297761    356189    462788
# 1379    192767    250734    297762    356191    463800
# 1380    192813    250766    297789    356200    464111
#
# [1381 rows x 21 columns]

# %%
d = pd.DataFrame(0, index=np.arange(len(data)), columns=feature_list)
